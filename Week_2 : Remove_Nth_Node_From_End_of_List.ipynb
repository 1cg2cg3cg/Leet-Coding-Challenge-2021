# %% [markdown]
# <a href="https://colab.research.google.com/github/1cg2cg3cg/April-LeetCoding-Challenge-2021/blob/main/Week_2%20%3A%20Remove_Nth_Node_From_End_of_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def removeNthFromEnd(self, head: ListNode, n: int) -> ListNode:
        
        slow = head
        while slow :
            
            fast = slow
            for i in range(n+1) :   # check val far from current node
                fast = fast.next
                
                if not fast and i < n : # have to remove 1st node
                    head = head.next
                    return head
            # to remove Nth node, we have to link N-1th node to N+1 Node
            if not fast :   
                slow.next = slow.next.next
                return head
            
            slow = slow.next    # move to next node
        
        return head
